# %%
import geopandas as gpd
import pandas as pd
df = pd.read_csv('flee-release/simulation_results.csv').T

# %%
df.head(10).plot()

# %%
df = df.reset_index()
df.columns = ['name'] + ['run' + str(i) for i in range(32)]
# drop unnamed business
df = df.iloc[1:]
df.head()
# Out:
#              name  run0  run1  run2  run3  run4  run5  run6  run7  run8  \
# 1  Abu Al-Khaseeb     0     3     2     0     1     3     6     6     3
# 2      Abu Ghraib     1     1     1     0     0     1     1     2     3
# 3         Adhamia     0     0     1     1     2     3     3     3     3
# 4            Afaq     1     1     2     4     3     4     2     3     4
# 5    Ain Al-Tamur     0     1     0     0     1     2     4     4     4
#
#    ...    run22  run23  run24  run25  run26  run27  run28  run29  run30  run31
# 1  ...       10     10     10      6      6      4      5      8      7      6
# 2  ...       11      9      7      8     15     17     10     10     12     15
# 3  ...       15     13     15     18     19     18     17     20     21     22
# 4  ...        7      8      6      9     10     10      8      9      9     11
# 5  ...        6      6      4      6     11      7      8      8      7     10
#
# [5 rows x 33 columns]

# %%
locs = gpd.read_file('locations_geodata.shp').merge(df, on = 'name')

# %%
locs.plot(column = 'run31')
